# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Variáveis & Tipos de Dados
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# Aluna: Maria Luiza Cordeiro
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Google Colab;</li>
#   <li>Variáveis;</li>
#   <li>Números;</li>
#   <li><i>Strings;</i></li>
#   <li>Boleanos.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Google Colab

# %% [markdown]
# Crie uma célula de código que escreva o texto "Olá mundo!", utilize o comando `print`.

# %%
print("Hello, World!")
print("Olá mundo!")
# Out:
# Hello, World!
# Olá mundo!

# %% [markdown]
# Crie uma célua de texto e adicione uma imagem.

# %% [markdown]
# ![july-13-2019-star-cluster-ngc-346.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Números

# %% [markdown]
# Preencha as células de código para preencher os valores de (A), (B) e (C) na tabela de ticket médio abaixo:
#
# <br>
#
# | Dia   | Valor Total Vendas | Qtd Total Vendas | Ticket Medio |
# |-------|--------------------|------------------|--------------|
# | 19/01 | (A)                | 3                | 320.52       |
# | 20/01 | 834.47             | (B)              | 119.21       |
# | 23/01 | 15378.12           | 5                | (C)          |

# %%
# (A)
qtd_19_01 = 3
tkt_19_01 = 320.52
vtv_19_01 = qtd_19_01 * tkt_19_01
print("(A) =", vtv_19_01)
# Out:
# (A) = 961.56

# %%
# (B)
vtv_20_01 = 834.47
tkt_20_01 = 119.21
qtd_20_01 = vtv_20_01 / tkt_20_01
print(qtd_20_01)
print("(B) =", int(qtd_20_01))
# Out:
# 7.000000000000001
# (B) = 7

# %%
# (C)
vtv_23_01 = 15378.12
qtd_23_01 = 5
tkt_23_01 = vtv_23_01 / qtd_23_01
print("(C) =", tkt_23_01)
# Out:
# (C) = 3075.6240000000003

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Strings

# %% [markdown]
# Aplique três métodos distintos na *string* abaixo, você pode conferir alguns métodos neste [link](https://www.w3schools.com/python/python_ref_string.asp):

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.' 
print(cancao.casefold())
print(cancao.isalnum(), "-> relacionado a se todos os caracteres são alfanuméricos") 
print(cancao.find('mundo'), "-> posição da palavra mundo")
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.
# False -> relacionado a se todos os caracteres são alfanuméricos
# 5 -> posição da palavra mundo

# %% [markdown]
# Extraia da string abaixo o valor da taxa **selic** na variável `selic` e o valor do **ano** na variavel `ano`. Imprima os valores na tela.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
selic = noticia[12:17]
print(selic)
ano = noticia[62]
print(ano)
# Out:
# 2,75%
# 6

# %% [markdown]
# ---

# %% [markdown]
# ## 4\. Booleanos

# %% [markdown]
# Utilize a tabela da verdade para responder: qual o valor da variável x?

# %%
a = False
b = True

x = not a & b

print("x =", x)

# x é verdadeiro, pois, ao colocar o operador not na frente de 'a', 'a' se torna verdadeiro. Com isso, sendo A "e" B verdadeiros, segundo a tabela verdade, só resta ao x ser verdadeiro
# Out:
# x = True
